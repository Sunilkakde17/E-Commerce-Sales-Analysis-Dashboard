# %% [markdown]
# EDA CODE

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/ecommerce_sales.csv")

df.shape
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_id             900 non-null    int64
#  1   order_date           900 non-null    object
#  2   customer_id          900 non-null    int64
#  3   customer_segment     900 non-null    object
#  4   region               900 non-null    object
#  5   state                900 non-null    object
#  6   city                 900 non-null    object
#  7   product_category     900 non-null    object
#  8   product_subcategory  900 non-null    object
#  9   product_name         900 non-null    object
#  10  quantity             900 non-null    int64
#  11  unit_price           900 non-null    int64
#  12  discount             900 non-null    float64
#  13  revenue              900 non-null    float64
#  14  cost                 900 non-null    float64
#  15  profit               900 non-null    float64
# dtypes: float64(4), int64(4), object(8)
# memory usage: 112.6+ KB
# order_id               0
# order_date             0
# customer_id            0
# customer_segment       0
# region                 0
# state                  0
# city                   0
# product_category       0
# product_subcategory    0
# product_name           0
# quantity               0
# unit_price             0
# discount               0
# revenue                0
# cost                   0
# profit                 0
# dtype: int64

# %% [markdown]
# Revenue Distribution

# %%
sns.histplot(df['revenue'], bins=30)
plt.title("Revenue Distribution")
plt.show()

# %% [markdown]
# Profit Distribution

# %%
sns.histplot(df['profit'], bins=30)
plt.title("Profit Distribution")
plt.show()

# %% [markdown]
# Sales by Region

# %%
df.groupby('region')['revenue'].sum().plot(kind='bar')
plt.title("Sales by Region")
plt.show()

# %% [markdown]
# Monthly Revenue Trend

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['month'] = df['order_date'].dt.to_period('M')

monthly_sales = df.groupby('month')['revenue'].sum()

monthly_sales.plot(kind='line')
plt.title("Monthly Revenue Trend")
plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
sns.heatmap(df[['quantity','unit_price','discount','revenue','profit']].corr(), annot=True)
plt.show()
